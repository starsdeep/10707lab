# %% [markdown]
# # Problem 5

# %%
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from data_loader import load_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver
from cs231n.classifiers.rbm import *
from cs231n.classifiers.autoencoder import *
import pickle as pickle
from visualize import plot_filters

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
data = load_data()

def plot_solver(solver):
    plt.subplot(2, 1, 1)
    plt.title('Training loss')
    plt.plot(solver.loss_history, 'o')
    plt.xlabel('Iteration')

    plt.subplot(2, 1, 2)
    plt.title('Reconstruction Cross Entropy Error')
    plt.plot(solver.train_reconstruct_error_history, '-o', label='train')
    plt.plot(solver.val_reconstruct_error_history, '-o', label='val')
    plt.plot([0.5] * len(solver.val_acc_history), 'k--')
    plt.xlabel('Epoch')
    plt.legend(loc='lower right')
    plt.gcf().set_size_inches(15, 12)
    plt.show()

def plot_solver_acc(solver):
    plt.subplot(2, 1, 1)
    plt.title('Training loss')
    plt.plot(solver.loss_history, 'o')
    plt.xlabel('Iteration')

    plt.subplot(2, 1, 2)
    plt.title('Classification Accuracy')
    plt.plot(solver.train_acc_history, '-o', label='train')
    plt.plot(solver.val_acc_history, '-o', label='val')
    plt.plot([0.5] * len(solver.val_acc_history), 'k--')
    plt.xlabel('Epoch')
    plt.legend(loc='lower right')
    plt.gcf().set_size_inches(15, 12)
    plt.show()

# %% [markdown]
# ## a. Basic generalization
#
# Answer:
#
# The reconstructed cross entropy error on validation set is little higher than in training set. When learned W is ploted as 100 28x28 images we can see the RBM do learned some useful features from images. We can see some learned patterns of edges from hand-written digits.

# %%
model1 = RBM()
solver1 = Solver(model1, data, verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-3}, print_every=50, lr_decay=0.9, num_epochs=20, batch_size=100)
solver1.train_unsupervise()
plot_solver(solver1)

weights = model1.params['W'].T
weights = weights.reshape(100, 28, 28)
plot_filters(weights)

# %% [markdown]
# ## b. Number of CD steps
#
# Answer:
#
# As the experiments show below, when k increases, it didn't improve our RBM model in terms of convergence and generalization. Actually when k increase, it increases model's reconstruction cross entropy error both on training set and validation set.

# %%
model2 = RBM(k=5)
solver2 = Solver(model2, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-3}, \
                 print_every=50, lr_decay=0.9, num_epochs=20, batch_size=100)
solver2.train_unsupervise()
plot_solver(solver2)

# %%
model3 = RBM(k=10)
solver3 = Solver(model3, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-3}, \
                 print_every=50, lr_decay=0.9, num_epochs=20, batch_size=100)
solver3.train_unsupervise()
plot_solver(solver3)

# %%
model4 = RBM(k=20)
solver4 = Solver(model4, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-3}, \
                 print_every=50, lr_decay=0.9, num_epochs=20, batch_size=100)
solver4.train_unsupervise()
plot_solver(solver4)

# %% [markdown]
# ## c. Sampling from the RBM model
#
# Answer:
#
# The sampled images look like handwritten digits when means the RBM model do learned some useful results. Also we find
# the the 100 sampled images are very similar. Because even initial state of the image are different, but after
# 1000 Gibbs steps, their distribution converge to a stable distribution.

# %%
sampled_imgs = np.reshape(model1.sample_imgs(100),(100,28,28))
plot_filters(sampled_imgs)
# Out:
# 0
# 20
# 40
# 60
# 80

# %% [markdown]
# ## d. Unsupervised Learning as pretraining
#
# Answer:
#
# Using unsupervised learning as pretraining could improve model's performance. When using random initialization, the best classification accuracy on validation set is 0.832. When using RBM model's parameter as initialization, the final accuracy of the model on validation set increases to 0.851.

# %%
import pickle as pickle
from cs231n.classifiers.fc_net import *

checkpoint = pickle.load(open('RBM_epoch_10.pkl', 'rb'))
rbm_params = checkpoint['model']

model = TwoLayerNet(input_dim=28*28, weight_scale=1e-2, init='uniform')
solver = Solver(model, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-2}, print_every=100, \
                lr_decay=0.9, num_epochs=200, batch_size=50)
solver.train()
solver.check_accuracy(data['X_test'], data['y_test'])
plot_solver_acc(solver)

# %%
model = TwoLayerNet(input_dim=28*28, init='uniform')
model.params['W1'] = rbm_params['W']
solver = Solver(model, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-2}, print_every=500, \
                lr_decay=0.9, num_epochs=200, batch_size=50)
solver.train()
solver.check_accuracy(data['X_test'], data['y_test'])
plot_solver_acc(solver)

# %% [markdown]
# ## d. Autoencoder
#
# The figure of learned filters shows Autoencoder learned some useful features. But the filters of Autoencoder does not look good as RBM(see Section a. Basic generalization).
#
# When using random initialization, the best classification accuracy on validation set is 0.832. When using Autoencoder model's parameter as initialization, the final accuracy of the model on validation set increases to 0.839.

# %%
from cs231n.classifiers.autoencoder import *
model = Autoencoder(input_dim=28*28, weight_scale=1e-1)
solver = Solver(model, data,  verbose=False, checkpoint_name='Autoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=100, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)

# %%
weights = model.params['W1'].T
weights = weights.reshape(100, 28, 28)
plot_filters(weights)

# %%
checkpoint = pickle.load(open('Autoencoder_epoch_200.pkl', 'rb'))
autoencoder_params = checkpoint['model']

model = TwoLayerNet(input_dim=28*28, init='uniform')
model.params['W1'] = autoencoder_params['W1']
solver = Solver(model, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-2}, print_every=500, \
                lr_decay=0.9, num_epochs=100, batch_size=50)
solver.train()
solver.check_accuracy(data['X_test'], data['y_test'])
plot_solver_acc(solver)

# %% [markdown]
# ## f. Denoising Autoencoder
#
# The figure of learned filters shows Denoising Autoencoder learned some useful features. But the filters of Denoising Autoencoder does not look good as RBM(see Section a. Basic generalization).
#
# When using random initialization, the best classification accuracy on validation set is 0.832. When using Denoising Autoencoder model's parameter as initialization, the final accuracy of the model on validation set increases to 0.845.
# When using as pretraining for some supervised models, the performance ranking of these models are RBM(0.851) > Denoising Autoencoder(0.845) > Authencoder(0.839).

# %%
from cs231n.classifiers.autoencoder import *
model = Autoencoder(input_dim=28*28, weight_scale=1e-1, dropout_level=0.2)
solver = Solver(model, data,  verbose=False, checkpoint_name='DAutoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=100, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)

# %%
weights = model.params['W1'].T
weights = weights.reshape(100, 28, 28)
plot_filters(weights)

# %%
checkpoint = pickle.load(open('DAutoencoder_epoch_100.pkl', 'rb'))
autoencoder_params = checkpoint['model']

model = TwoLayerNet(input_dim=28*28, init='uniform')
model.params['W1'] = autoencoder_params['W1']
solver = Solver(model, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-2}, print_every=500, \
                lr_decay=0.9, num_epochs=100, batch_size=50)
solver.train()
solver.check_accuracy(data['X_test'], data['y_test'])
plot_solver_acc(solver)

# %% [markdown]
# ## g.  Number of hidden Units
#
# Ansewr:
#
# When size of hidden units increase, the reconstruction error of all models increases, both in training set and validation set. Thus, the increse the hidden units improves the convergence and generazlization of the network. However, archieve good performance in reconstruction of input does not ensure the model learned useful features. Those models are often used as pretraining for some supervised models. In this case it is not the more hidden layer the better. We should choose a value to forse the model to learn useful features so that can improve the performance of supervised models when using its parameter as initialization.

# %%
rbm1 = RBM(hidden_dim=50)
rbm_solver1 = Solver(rbm1, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-3}, 、
                     print_every=50, lr_decay=0.9, num_epochs=20, batch_size=100)
rbm_solver1.train_unsupervise()
plot_solver(rbm_solver1 )
# Out:
# (Iteration 1 / 600) loss: 563.520776
# (Epoch 0 / 20) train reconstruct_error: 467.639974; val_reconstruct_error: 465.381376
# (Epoch 1 / 20) train reconstruct_error: 239.012109; val_reconstruct_error: 240.651201
# (Iteration 51 / 600) loss: 217.092830
# (Epoch 2 / 20) train reconstruct_error: 207.638371; val_reconstruct_error: 209.601232
# (Epoch 3 / 20) train reconstruct_error: 192.490244; val_reconstruct_error: 194.555125
# (Iteration 101 / 600) loss: 189.508322
# (Epoch 4 / 20) train reconstruct_error: 183.427310; val_reconstruct_error: 185.497648
# (Epoch 5 / 20) train reconstruct_error: 176.676341; val_reconstruct_error: 178.867615
# (Iteration 151 / 600) loss: 178.673058
# (Epoch 6 / 20) train reconstruct_error: 171.942654; val_reconstruct_error: 174.618444
# (Iteration 201 / 600) loss: 172.968561
# (Epoch 7 / 20) train reconstruct_error: 168.541103; val_reconstruct_error: 171.085702
# (Epoch 8 / 20) train reconstruct_error: 165.519928; val_reconstruct_error: 168.246264
# (Iteration 251 / 600) loss: 154.139096
# (Epoch 9 / 20) train reconstruct_error: 163.104416; val_reconstruct_error: 165.985332
# (Epoch 10 / 20) train reconstruct_error: 161.462082; val_reconstruct_error: 163.659264
# (Iteration 301 / 600) loss: 162.634473
# (Epoch 11 / 20) train reconstruct_error: 159.654906; val_reconstruct_error: 162.615317
# (Iteration 351 / 600) loss: 162.020154
# (Epoch 12 / 20) train reconstruct_error: 158.175823; val_reconstruct_error: 160.755422
# (Epoch 13 / 20) train reconstruct_error: 157.014334; val_reconstruct_error: 159.874242
# (Iteration 401 / 600) loss: 160.692700
# (Epoch 14 / 20) train reconstruct_error: 156.038886; val_reconstruct_error: 158.845278
# (Epoch 15 / 20) train reconstruct_error: 155.022455; val_reconstruct_error: 158.283224
# (Iteration 451 / 600) loss: 160.940920
# (Epoch 16 / 20) train reconstruct_error: 154.345885; val_reconstruct_error: 157.218953
# (Iteration 501 / 600) loss: 159.440786
# (Epoch 17 / 20) train reconstruct_error: 153.665552; val_reconstruct_error: 156.600745
# (Epoch 18 / 20) train reconstruct_error: 153.095257; val_reconstruct_error: 155.851830
# (Iteration 551 / 600) loss: 152.698113
# (Epoch 19 / 20) train reconstruct_error: 152.580667; val_reconstruct_error: 155.741104
# (Epoch 20 / 20) train reconstruct_error: 152.097813; val_reconstruct_error: 155.123514

# %%
rbm2 = RBM(hidden_dim=100)
rbm_solver2 = Solver(rbm2, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-3}, print_every=50, lr_decay=0.9, num_epochs=20, batch_size=100)
rbm_solver2.train_unsupervise()
plot_solver(rbm_solver2 )
# Out:
# (Iteration 1 / 600) loss: 579.745224
# (Epoch 0 / 20) train reconstruct_error: 395.218664; val_reconstruct_error: 394.563587
# (Epoch 1 / 20) train reconstruct_error: 203.925344; val_reconstruct_error: 205.439829
# (Iteration 51 / 600) loss: 179.258415
# (Epoch 2 / 20) train reconstruct_error: 176.130851; val_reconstruct_error: 177.682193
# (Epoch 3 / 20) train reconstruct_error: 163.503544; val_reconstruct_error: 165.567224
# (Iteration 101 / 600) loss: 158.916456
# (Epoch 4 / 20) train reconstruct_error: 155.888738; val_reconstruct_error: 157.563658
# (Epoch 5 / 20) train reconstruct_error: 150.631979; val_reconstruct_error: 152.917366
# (Iteration 151 / 600) loss: 155.904787
# (Epoch 6 / 20) train reconstruct_error: 146.923613; val_reconstruct_error: 148.751290
# (Iteration 201 / 600) loss: 146.537041
# (Epoch 7 / 20) train reconstruct_error: 143.974645; val_reconstruct_error: 146.376431
# (Epoch 8 / 20) train reconstruct_error: 141.331874; val_reconstruct_error: 143.928432
# (Iteration 251 / 600) loss: 139.955259
# (Epoch 9 / 20) train reconstruct_error: 139.480850; val_reconstruct_error: 141.859110
# (Epoch 10 / 20) train reconstruct_error: 137.938366; val_reconstruct_error: 140.501156
# (Iteration 301 / 600) loss: 145.389072
# (Epoch 11 / 20) train reconstruct_error: 136.594740; val_reconstruct_error: 139.035045
# (Iteration 351 / 600) loss: 141.447864
# (Epoch 12 / 20) train reconstruct_error: 135.357233; val_reconstruct_error: 138.109779
# (Epoch 13 / 20) train reconstruct_error: 134.470486; val_reconstruct_error: 136.974969
# (Iteration 401 / 600) loss: 128.236191
# (Epoch 14 / 20) train reconstruct_error: 133.581232; val_reconstruct_error: 136.291202
# (Epoch 15 / 20) train reconstruct_error: 132.833259; val_reconstruct_error: 135.788082
# (Iteration 451 / 600) loss: 138.100004
# (Epoch 16 / 20) train reconstruct_error: 132.319735; val_reconstruct_error: 135.063263
# (Iteration 501 / 600) loss: 130.690498
# (Epoch 17 / 20) train reconstruct_error: 131.840523; val_reconstruct_error: 134.109747
# (Epoch 18 / 20) train reconstruct_error: 131.323671; val_reconstruct_error: 134.188523
# (Iteration 551 / 600) loss: 137.561719
# (Epoch 19 / 20) train reconstruct_error: 130.780709; val_reconstruct_error: 133.541660
# (Epoch 20 / 20) train reconstruct_error: 130.391175; val_reconstruct_error: 133.112004

# %%
rbm3 = RBM(hidden_dim=200)
rbm_solver3 = Solver(rbm3, data, verbose=False,  update_rule='sgd', optim_config={'learning_rate': 1e-3}, print_every=50, lr_decay=0.9, num_epochs=20, batch_size=100)
rbm_solver3.train_unsupervise()
plot_solver(rbm_solver3 )
# Out:
# (Iteration 1 / 600) loss: 632.636162
# (Epoch 0 / 20) train reconstruct_error: 320.879570; val_reconstruct_error: 322.132134
# (Epoch 1 / 20) train reconstruct_error: 171.092227; val_reconstruct_error: 172.521231
# (Iteration 51 / 600) loss: 151.889705
# (Epoch 2 / 20) train reconstruct_error: 150.747174; val_reconstruct_error: 152.332084
# (Epoch 3 / 20) train reconstruct_error: 140.904423; val_reconstruct_error: 142.447251
# (Iteration 101 / 600) loss: 142.277262
# (Epoch 4 / 20) train reconstruct_error: 134.699106; val_reconstruct_error: 136.651450
# (Epoch 5 / 20) train reconstruct_error: 130.537917; val_reconstruct_error: 132.474932
# (Iteration 151 / 600) loss: 131.261428
# (Epoch 6 / 20) train reconstruct_error: 127.301757; val_reconstruct_error: 129.396590
# (Iteration 201 / 600) loss: 121.713996
# (Epoch 7 / 20) train reconstruct_error: 124.837288; val_reconstruct_error: 127.189054
# (Epoch 8 / 20) train reconstruct_error: 123.052474; val_reconstruct_error: 125.369201
# (Iteration 251 / 600) loss: 121.840822
# (Epoch 9 / 20) train reconstruct_error: 121.376674; val_reconstruct_error: 123.732400
# (Epoch 10 / 20) train reconstruct_error: 120.069465; val_reconstruct_error: 122.494653
# (Iteration 301 / 600) loss: 115.309377
# (Epoch 11 / 20) train reconstruct_error: 118.883975; val_reconstruct_error: 121.475508
# (Iteration 351 / 600) loss: 113.471728
# (Epoch 12 / 20) train reconstruct_error: 118.122472; val_reconstruct_error: 120.725945
# (Epoch 13 / 20) train reconstruct_error: 117.426824; val_reconstruct_error: 119.804275
# (Iteration 401 / 600) loss: 114.128688
# (Epoch 14 / 20) train reconstruct_error: 116.699299; val_reconstruct_error: 119.039319
# (Epoch 15 / 20) train reconstruct_error: 116.173310; val_reconstruct_error: 118.807839
# (Iteration 451 / 600) loss: 113.653062
# (Epoch 16 / 20) train reconstruct_error: 115.661553; val_reconstruct_error: 118.134173
# (Iteration 501 / 600) loss: 120.575362
# (Epoch 17 / 20) train reconstruct_error: 115.254556; val_reconstruct_error: 117.824987
# (Epoch 18 / 20) train reconstruct_error: 114.725854; val_reconstruct_error: 117.425967
# (Iteration 551 / 600) loss: 111.172264
# (Epoch 19 / 20) train reconstruct_error: 114.386261; val_reconstruct_error: 117.217107
# (Epoch 20 / 20) train reconstruct_error: 114.266640; val_reconstruct_error: 116.959526

# %%
rbm4 = RBM(hidden_dim=500)
rbm_solver4 = Solver(rbm4, data,  verbose=False, update_rule='sgd', optim_config={'learning_rate': 1e-3}, print_every=50, lr_decay=0.9, num_epochs=20, batch_size=100)
rbm_solver4.train_unsupervise()
plot_solver(rbm_solver4 )
# Out:
# (Iteration 1 / 600) loss: 711.858720
# (Epoch 0 / 20) train reconstruct_error: 241.571318; val_reconstruct_error: 242.134773
# (Epoch 1 / 20) train reconstruct_error: 144.440297; val_reconstruct_error: 145.823015
# (Iteration 51 / 600) loss: 131.841737
# (Epoch 2 / 20) train reconstruct_error: 128.687056; val_reconstruct_error: 130.185141
# (Epoch 3 / 20) train reconstruct_error: 120.439064; val_reconstruct_error: 122.212378
# (Iteration 101 / 600) loss: 125.707468
# (Epoch 4 / 20) train reconstruct_error: 115.393910; val_reconstruct_error: 117.412470
# (Epoch 5 / 20) train reconstruct_error: 111.661488; val_reconstruct_error: 113.768708
# (Iteration 151 / 600) loss: 112.468255
# (Epoch 6 / 20) train reconstruct_error: 109.220277; val_reconstruct_error: 111.385369
# (Iteration 201 / 600) loss: 108.127703
# (Epoch 7 / 20) train reconstruct_error: 107.305051; val_reconstruct_error: 109.599198
# (Epoch 8 / 20) train reconstruct_error: 105.770795; val_reconstruct_error: 107.889773
# (Iteration 251 / 600) loss: 105.642466
# (Epoch 9 / 20) train reconstruct_error: 104.302341; val_reconstruct_error: 106.607431
# (Epoch 10 / 20) train reconstruct_error: 103.361187; val_reconstruct_error: 105.734991
# (Iteration 301 / 600) loss: 101.111266
# (Epoch 11 / 20) train reconstruct_error: 102.306779; val_reconstruct_error: 104.995945
# (Iteration 351 / 600) loss: 99.635007
# (Epoch 12 / 20) train reconstruct_error: 101.605248; val_reconstruct_error: 104.061074
# (Epoch 13 / 20) train reconstruct_error: 101.147639; val_reconstruct_error: 103.632846
# (Iteration 401 / 600) loss: 100.619590
# (Epoch 14 / 20) train reconstruct_error: 100.254087; val_reconstruct_error: 103.094192
# (Epoch 15 / 20) train reconstruct_error: 99.981319; val_reconstruct_error: 102.416124
# (Iteration 451 / 600) loss: 107.090907
# (Epoch 16 / 20) train reconstruct_error: 99.549924; val_reconstruct_error: 102.155321
# (Iteration 501 / 600) loss: 101.756360
# (Epoch 17 / 20) train reconstruct_error: 99.328058; val_reconstruct_error: 101.804374
# (Epoch 18 / 20) train reconstruct_error: 99.003730; val_reconstruct_error: 101.723617
# (Iteration 551 / 600) loss: 101.672853
# (Epoch 19 / 20) train reconstruct_error: 98.639698; val_reconstruct_error: 101.260788
# (Epoch 20 / 20) train reconstruct_error: 98.379423; val_reconstruct_error: 101.201984

# %%
model = Autoencoder(input_dim=28*28, weight_scale=1e-1, hidden_dim=50)
solver = Solver(model, data, checkpoint_name='Autoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=50, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)
# Out:
# (Iteration 1 / 1500) loss: 91.539073
# Saving checkpoint to "Autoencoder_epoch_0.pkl"
# (Epoch 0 / 50) train reconstruct_error: 85.892860; val_reconstruct_error: 85.855716
# Saving checkpoint to "Autoencoder_epoch_1.pkl"
# (Epoch 1 / 50) train reconstruct_error: 36.603516; val_reconstruct_error: 36.744684
# Saving checkpoint to "Autoencoder_epoch_2.pkl"
# (Epoch 2 / 50) train reconstruct_error: 31.848121; val_reconstruct_error: 31.967942
# Saving checkpoint to "Autoencoder_epoch_3.pkl"
# (Epoch 3 / 50) train reconstruct_error: 29.548135; val_reconstruct_error: 29.648193
# Saving checkpoint to "Autoencoder_epoch_4.pkl"
# (Epoch 4 / 50) train reconstruct_error: 27.895159; val_reconstruct_error: 27.986436
# Saving checkpoint to "Autoencoder_epoch_5.pkl"
# (Epoch 5 / 50) train reconstruct_error: 26.617129; val_reconstruct_error: 26.703091
# Saving checkpoint to "Autoencoder_epoch_6.pkl"
# (Epoch 6 / 50) train reconstruct_error: 25.596696; val_reconstruct_error: 25.696123
# Saving checkpoint to "Autoencoder_epoch_7.pkl"
# (Epoch 7 / 50) train reconstruct_error: 24.778526; val_reconstruct_error: 24.876918
# Saving checkpoint to "Autoencoder_epoch_8.pkl"
# (Epoch 8 / 50) train reconstruct_error: 24.114038; val_reconstruct_error: 24.213852
# Saving checkpoint to "Autoencoder_epoch_9.pkl"
# (Epoch 9 / 50) train reconstruct_error: 23.573510; val_reconstruct_error: 23.676394
# Saving checkpoint to "Autoencoder_epoch_10.pkl"
# (Epoch 10 / 50) train reconstruct_error: 23.123651; val_reconstruct_error: 23.227086
# Saving checkpoint to "Autoencoder_epoch_11.pkl"
# (Epoch 11 / 50) train reconstruct_error: 22.751256; val_reconstruct_error: 22.853386
# Saving checkpoint to "Autoencoder_epoch_12.pkl"
# (Epoch 12 / 50) train reconstruct_error: 22.435895; val_reconstruct_error: 22.540141
# Saving checkpoint to "Autoencoder_epoch_13.pkl"
# (Epoch 13 / 50) train reconstruct_error: 22.169866; val_reconstruct_error: 22.276997
# Saving checkpoint to "Autoencoder_epoch_14.pkl"
# (Epoch 14 / 50) train reconstruct_error: 21.942974; val_reconstruct_error: 22.051347
# Saving checkpoint to "Autoencoder_epoch_15.pkl"
# (Epoch 15 / 50) train reconstruct_error: 21.748460; val_reconstruct_error: 21.857627
# Saving checkpoint to "Autoencoder_epoch_16.pkl"
# (Epoch 16 / 50) train reconstruct_error: 21.579836; val_reconstruct_error: 21.688007
# (Iteration 501 / 1500) loss: 20.692717
# Saving checkpoint to "Autoencoder_epoch_17.pkl"
# (Epoch 17 / 50) train reconstruct_error: 21.432437; val_reconstruct_error: 21.541516
# Saving checkpoint to "Autoencoder_epoch_18.pkl"
# (Epoch 18 / 50) train reconstruct_error: 21.305687; val_reconstruct_error: 21.416523
# Saving checkpoint to "Autoencoder_epoch_19.pkl"
# (Epoch 19 / 50) train reconstruct_error: 21.193927; val_reconstruct_error: 21.306669
# Saving checkpoint to "Autoencoder_epoch_20.pkl"
# (Epoch 20 / 50) train reconstruct_error: 21.096045; val_reconstruct_error: 21.209298
# Saving checkpoint to "Autoencoder_epoch_21.pkl"
# (Epoch 21 / 50) train reconstruct_error: 21.009971; val_reconstruct_error: 21.123992
# Saving checkpoint to "Autoencoder_epoch_22.pkl"
# (Epoch 22 / 50) train reconstruct_error: 20.934011; val_reconstruct_error: 21.047966
# Saving checkpoint to "Autoencoder_epoch_23.pkl"
# (Epoch 23 / 50) train reconstruct_error: 20.866623; val_reconstruct_error: 20.980194
# Saving checkpoint to "Autoencoder_epoch_24.pkl"
# (Epoch 24 / 50) train reconstruct_error: 20.807102; val_reconstruct_error: 20.921301
# Saving checkpoint to "Autoencoder_epoch_25.pkl"
# (Epoch 25 / 50) train reconstruct_error: 20.754621; val_reconstruct_error: 20.869003
# Saving checkpoint to "Autoencoder_epoch_26.pkl"
# (Epoch 26 / 50) train reconstruct_error: 20.707284; val_reconstruct_error: 20.822433
# Saving checkpoint to "Autoencoder_epoch_27.pkl"
# (Epoch 27 / 50) train reconstruct_error: 20.665409; val_reconstruct_error: 20.780883
# Saving checkpoint to "Autoencoder_epoch_28.pkl"
# (Epoch 28 / 50) train reconstruct_error: 20.628290; val_reconstruct_error: 20.744017
# Saving checkpoint to "Autoencoder_epoch_29.pkl"
# (Epoch 29 / 50) train reconstruct_error: 20.595046; val_reconstruct_error: 20.711220
# Saving checkpoint to "Autoencoder_epoch_30.pkl"
# (Epoch 30 / 50) train reconstruct_error: 20.565557; val_reconstruct_error: 20.681570
# Saving checkpoint to "Autoencoder_epoch_31.pkl"
# (Epoch 31 / 50) train reconstruct_error: 20.539324; val_reconstruct_error: 20.655240
# Saving checkpoint to "Autoencoder_epoch_32.pkl"
# (Epoch 32 / 50) train reconstruct_error: 20.515653; val_reconstruct_error: 20.631908
# Saving checkpoint to "Autoencoder_epoch_33.pkl"
# (Epoch 33 / 50) train reconstruct_error: 20.494488; val_reconstruct_error: 20.610988
# (Iteration 1001 / 1500) loss: 19.636975
# Saving checkpoint to "Autoencoder_epoch_34.pkl"
# (Epoch 34 / 50) train reconstruct_error: 20.475348; val_reconstruct_error: 20.592251
# Saving checkpoint to "Autoencoder_epoch_35.pkl"
# (Epoch 35 / 50) train reconstruct_error: 20.458318; val_reconstruct_error: 20.575293
# Saving checkpoint to "Autoencoder_epoch_36.pkl"
# (Epoch 36 / 50) train reconstruct_error: 20.443006; val_reconstruct_error: 20.560126
# Saving checkpoint to "Autoencoder_epoch_37.pkl"
# (Epoch 37 / 50) train reconstruct_error: 20.429331; val_reconstruct_error: 20.546728
# Saving checkpoint to "Autoencoder_epoch_38.pkl"
# (Epoch 38 / 50) train reconstruct_error: 20.417049; val_reconstruct_error: 20.534632
# Saving checkpoint to "Autoencoder_epoch_39.pkl"
# (Epoch 39 / 50) train reconstruct_error: 20.406018; val_reconstruct_error: 20.523676
# Saving checkpoint to "Autoencoder_epoch_40.pkl"
# (Epoch 40 / 50) train reconstruct_error: 20.396240; val_reconstruct_error: 20.513917
# Saving checkpoint to "Autoencoder_epoch_41.pkl"
# (Epoch 41 / 50) train reconstruct_error: 20.387331; val_reconstruct_error: 20.505116
# Saving checkpoint to "Autoencoder_epoch_42.pkl"
# (Epoch 42 / 50) train reconstruct_error: 20.379253; val_reconstruct_error: 20.497144
# Saving checkpoint to "Autoencoder_epoch_43.pkl"
# (Epoch 43 / 50) train reconstruct_error: 20.372058; val_reconstruct_error: 20.490017
# Saving checkpoint to "Autoencoder_epoch_44.pkl"
# (Epoch 44 / 50) train reconstruct_error: 20.365628; val_reconstruct_error: 20.483711
# Saving checkpoint to "Autoencoder_epoch_45.pkl"
# (Epoch 45 / 50) train reconstruct_error: 20.359866; val_reconstruct_error: 20.477942
# Saving checkpoint to "Autoencoder_epoch_46.pkl"
# (Epoch 46 / 50) train reconstruct_error: 20.354721; val_reconstruct_error: 20.472837
# Saving checkpoint to "Autoencoder_epoch_47.pkl"
# (Epoch 47 / 50) train reconstruct_error: 20.350044; val_reconstruct_error: 20.468209
# Saving checkpoint to "Autoencoder_epoch_48.pkl"
# (Epoch 48 / 50) train reconstruct_error: 20.345870; val_reconstruct_error: 20.464088
# Saving checkpoint to "Autoencoder_epoch_49.pkl"
# (Epoch 49 / 50) train reconstruct_error: 20.342115; val_reconstruct_error: 20.460395
# Saving checkpoint to "Autoencoder_epoch_50.pkl"
# (Epoch 50 / 50) train reconstruct_error: 20.338750; val_reconstruct_error: 20.457067

# %%
model = Autoencoder(input_dim=28*28, weight_scale=1e-1, hidden_dim=100)
solver = Solver(model, data, checkpoint_name='Autoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=50, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)
# Out:
# (Iteration 1 / 1500) loss: 96.741027
# Saving checkpoint to "Autoencoder_epoch_0.pkl"
# (Epoch 0 / 50) train reconstruct_error: 85.127916; val_reconstruct_error: 85.094108
# Saving checkpoint to "Autoencoder_epoch_1.pkl"
# (Epoch 1 / 50) train reconstruct_error: 31.150665; val_reconstruct_error: 31.227469
# Saving checkpoint to "Autoencoder_epoch_2.pkl"
# (Epoch 2 / 50) train reconstruct_error: 27.035937; val_reconstruct_error: 27.109469
# Saving checkpoint to "Autoencoder_epoch_3.pkl"
# (Epoch 3 / 50) train reconstruct_error: 24.693369; val_reconstruct_error: 24.769991
# Saving checkpoint to "Autoencoder_epoch_4.pkl"
# (Epoch 4 / 50) train reconstruct_error: 23.049923; val_reconstruct_error: 23.137380
# Saving checkpoint to "Autoencoder_epoch_5.pkl"
# (Epoch 5 / 50) train reconstruct_error: 21.850652; val_reconstruct_error: 21.948443
# Saving checkpoint to "Autoencoder_epoch_6.pkl"
# (Epoch 6 / 50) train reconstruct_error: 20.947758; val_reconstruct_error: 21.053541
# Saving checkpoint to "Autoencoder_epoch_7.pkl"
# (Epoch 7 / 50) train reconstruct_error: 20.250930; val_reconstruct_error: 20.357362
# Saving checkpoint to "Autoencoder_epoch_8.pkl"
# (Epoch 8 / 50) train reconstruct_error: 19.700095; val_reconstruct_error: 19.803805
# Saving checkpoint to "Autoencoder_epoch_9.pkl"
# (Epoch 9 / 50) train reconstruct_error: 19.254389; val_reconstruct_error: 19.361652
# Saving checkpoint to "Autoencoder_epoch_10.pkl"
# (Epoch 10 / 50) train reconstruct_error: 18.890543; val_reconstruct_error: 18.997803
# Saving checkpoint to "Autoencoder_epoch_11.pkl"
# (Epoch 11 / 50) train reconstruct_error: 18.590641; val_reconstruct_error: 18.695268
# Saving checkpoint to "Autoencoder_epoch_12.pkl"
# (Epoch 12 / 50) train reconstruct_error: 18.336869; val_reconstruct_error: 18.451013
# Saving checkpoint to "Autoencoder_epoch_13.pkl"
# (Epoch 13 / 50) train reconstruct_error: 18.123360; val_reconstruct_error: 18.236169
# Saving checkpoint to "Autoencoder_epoch_14.pkl"
# (Epoch 14 / 50) train reconstruct_error: 17.939942; val_reconstruct_error: 18.053874
# Saving checkpoint to "Autoencoder_epoch_15.pkl"
# (Epoch 15 / 50) train reconstruct_error: 17.781665; val_reconstruct_error: 17.897216
# Saving checkpoint to "Autoencoder_epoch_16.pkl"
# (Epoch 16 / 50) train reconstruct_error: 17.645445; val_reconstruct_error: 17.761544
# (Iteration 501 / 1500) loss: 18.133995
# Saving checkpoint to "Autoencoder_epoch_17.pkl"
# (Epoch 17 / 50) train reconstruct_error: 17.526521; val_reconstruct_error: 17.641045
# Saving checkpoint to "Autoencoder_epoch_18.pkl"
# (Epoch 18 / 50) train reconstruct_error: 17.423514; val_reconstruct_error: 17.537377
# Saving checkpoint to "Autoencoder_epoch_19.pkl"
# (Epoch 19 / 50) train reconstruct_error: 17.332857; val_reconstruct_error: 17.448517
# Saving checkpoint to "Autoencoder_epoch_20.pkl"
# (Epoch 20 / 50) train reconstruct_error: 17.252355; val_reconstruct_error: 17.368168
# Saving checkpoint to "Autoencoder_epoch_21.pkl"
# (Epoch 21 / 50) train reconstruct_error: 17.181495; val_reconstruct_error: 17.297904
# Saving checkpoint to "Autoencoder_epoch_22.pkl"
# (Epoch 22 / 50) train reconstruct_error: 17.118748; val_reconstruct_error: 17.236327
# Saving checkpoint to "Autoencoder_epoch_23.pkl"
# (Epoch 23 / 50) train reconstruct_error: 17.063174; val_reconstruct_error: 17.181853
# Saving checkpoint to "Autoencoder_epoch_24.pkl"
# (Epoch 24 / 50) train reconstruct_error: 17.014343; val_reconstruct_error: 17.132887
# Saving checkpoint to "Autoencoder_epoch_25.pkl"
# (Epoch 25 / 50) train reconstruct_error: 16.970819; val_reconstruct_error: 17.090174
# Saving checkpoint to "Autoencoder_epoch_26.pkl"
# (Epoch 26 / 50) train reconstruct_error: 16.932116; val_reconstruct_error: 17.052573
# Saving checkpoint to "Autoencoder_epoch_27.pkl"
# (Epoch 27 / 50) train reconstruct_error: 16.897745; val_reconstruct_error: 17.018320
# Saving checkpoint to "Autoencoder_epoch_28.pkl"
# (Epoch 28 / 50) train reconstruct_error: 16.866990; val_reconstruct_error: 16.987660
# Saving checkpoint to "Autoencoder_epoch_29.pkl"
# (Epoch 29 / 50) train reconstruct_error: 16.839771; val_reconstruct_error: 16.960998
# Saving checkpoint to "Autoencoder_epoch_30.pkl"
# (Epoch 30 / 50) train reconstruct_error: 16.815265; val_reconstruct_error: 16.936562
# Saving checkpoint to "Autoencoder_epoch_31.pkl"
# (Epoch 31 / 50) train reconstruct_error: 16.793306; val_reconstruct_error: 16.914615
# Saving checkpoint to "Autoencoder_epoch_32.pkl"
# (Epoch 32 / 50) train reconstruct_error: 16.773775; val_reconstruct_error: 16.895117
# Saving checkpoint to "Autoencoder_epoch_33.pkl"
# (Epoch 33 / 50) train reconstruct_error: 16.756209; val_reconstruct_error: 16.877838
# (Iteration 1001 / 1500) loss: 15.757058
# Saving checkpoint to "Autoencoder_epoch_34.pkl"
# (Epoch 34 / 50) train reconstruct_error: 16.740521; val_reconstruct_error: 16.862578
# Saving checkpoint to "Autoencoder_epoch_35.pkl"
# (Epoch 35 / 50) train reconstruct_error: 16.726415; val_reconstruct_error: 16.848461
# Saving checkpoint to "Autoencoder_epoch_36.pkl"
# (Epoch 36 / 50) train reconstruct_error: 16.713683; val_reconstruct_error: 16.835987
# Saving checkpoint to "Autoencoder_epoch_37.pkl"
# (Epoch 37 / 50) train reconstruct_error: 16.702280; val_reconstruct_error: 16.824588
# Saving checkpoint to "Autoencoder_epoch_38.pkl"
# (Epoch 38 / 50) train reconstruct_error: 16.692056; val_reconstruct_error: 16.814675
# Saving checkpoint to "Autoencoder_epoch_39.pkl"
# (Epoch 39 / 50) train reconstruct_error: 16.682864; val_reconstruct_error: 16.805521
# Saving checkpoint to "Autoencoder_epoch_40.pkl"
# (Epoch 40 / 50) train reconstruct_error: 16.674573; val_reconstruct_error: 16.797298
# Saving checkpoint to "Autoencoder_epoch_41.pkl"
# (Epoch 41 / 50) train reconstruct_error: 16.667150; val_reconstruct_error: 16.789994
# Saving checkpoint to "Autoencoder_epoch_42.pkl"
# (Epoch 42 / 50) train reconstruct_error: 16.660470; val_reconstruct_error: 16.783670
# Saving checkpoint to "Autoencoder_epoch_43.pkl"
# (Epoch 43 / 50) train reconstruct_error: 16.654520; val_reconstruct_error: 16.777884
# Saving checkpoint to "Autoencoder_epoch_44.pkl"
# (Epoch 44 / 50) train reconstruct_error: 16.649202; val_reconstruct_error: 16.772611
# Saving checkpoint to "Autoencoder_epoch_45.pkl"
# (Epoch 45 / 50) train reconstruct_error: 16.644385; val_reconstruct_error: 16.767887
# Saving checkpoint to "Autoencoder_epoch_46.pkl"
# (Epoch 46 / 50) train reconstruct_error: 16.640079; val_reconstruct_error: 16.763623
# Saving checkpoint to "Autoencoder_epoch_47.pkl"
# (Epoch 47 / 50) train reconstruct_error: 16.636184; val_reconstruct_error: 16.759793
# Saving checkpoint to "Autoencoder_epoch_48.pkl"
# (Epoch 48 / 50) train reconstruct_error: 16.632667; val_reconstruct_error: 16.756310
# Saving checkpoint to "Autoencoder_epoch_49.pkl"
# (Epoch 49 / 50) train reconstruct_error: 16.629513; val_reconstruct_error: 16.753191
# Saving checkpoint to "Autoencoder_epoch_50.pkl"
# (Epoch 50 / 50) train reconstruct_error: 16.626678; val_reconstruct_error: 16.750341

# %%
model = Autoencoder(input_dim=28*28, weight_scale=1e-1, hidden_dim=200)
solver = Solver(model, data, checkpoint_name='Autoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=50, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)
# Out:
# (Iteration 1 / 1500) loss: 97.942629
# Saving checkpoint to "Autoencoder_epoch_0.pkl"
# (Epoch 0 / 50) train reconstruct_error: 77.730755; val_reconstruct_error: 77.673560
# Saving checkpoint to "Autoencoder_epoch_1.pkl"
# (Epoch 1 / 50) train reconstruct_error: 24.798517; val_reconstruct_error: 24.830378
# Saving checkpoint to "Autoencoder_epoch_2.pkl"
# (Epoch 2 / 50) train reconstruct_error: 21.475023; val_reconstruct_error: 21.517299
# Saving checkpoint to "Autoencoder_epoch_3.pkl"
# (Epoch 3 / 50) train reconstruct_error: 19.545723; val_reconstruct_error: 19.590179
# Saving checkpoint to "Autoencoder_epoch_4.pkl"
# (Epoch 4 / 50) train reconstruct_error: 18.230197; val_reconstruct_error: 18.286263
# Saving checkpoint to "Autoencoder_epoch_5.pkl"
# (Epoch 5 / 50) train reconstruct_error: 17.276274; val_reconstruct_error: 17.339820
# Saving checkpoint to "Autoencoder_epoch_6.pkl"
# (Epoch 6 / 50) train reconstruct_error: 16.556663; val_reconstruct_error: 16.630875
# Saving checkpoint to "Autoencoder_epoch_7.pkl"
# (Epoch 7 / 50) train reconstruct_error: 15.999600; val_reconstruct_error: 16.080887
# Saving checkpoint to "Autoencoder_epoch_8.pkl"
# (Epoch 8 / 50) train reconstruct_error: 15.554099; val_reconstruct_error: 15.642143
# Saving checkpoint to "Autoencoder_epoch_9.pkl"
# (Epoch 9 / 50) train reconstruct_error: 15.190938; val_reconstruct_error: 15.286346
# Saving checkpoint to "Autoencoder_epoch_10.pkl"
# (Epoch 10 / 50) train reconstruct_error: 14.891130; val_reconstruct_error: 14.994845
# Saving checkpoint to "Autoencoder_epoch_11.pkl"
# (Epoch 11 / 50) train reconstruct_error: 14.642724; val_reconstruct_error: 14.750616
# Saving checkpoint to "Autoencoder_epoch_12.pkl"
# (Epoch 12 / 50) train reconstruct_error: 14.431554; val_reconstruct_error: 14.546070
# Saving checkpoint to "Autoencoder_epoch_13.pkl"
# (Epoch 13 / 50) train reconstruct_error: 14.250628; val_reconstruct_error: 14.363436
# Saving checkpoint to "Autoencoder_epoch_14.pkl"
# (Epoch 14 / 50) train reconstruct_error: 14.094241; val_reconstruct_error: 14.208139
# Saving checkpoint to "Autoencoder_epoch_15.pkl"
# (Epoch 15 / 50) train reconstruct_error: 13.959136; val_reconstruct_error: 14.075472
# Saving checkpoint to "Autoencoder_epoch_16.pkl"
# (Epoch 16 / 50) train reconstruct_error: 13.843350; val_reconstruct_error: 13.961434
# (Iteration 501 / 1500) loss: 14.350516
# Saving checkpoint to "Autoencoder_epoch_17.pkl"
# (Epoch 17 / 50) train reconstruct_error: 13.740564; val_reconstruct_error: 13.861943
# Saving checkpoint to "Autoencoder_epoch_18.pkl"
# (Epoch 18 / 50) train reconstruct_error: 13.651361; val_reconstruct_error: 13.774713
# Saving checkpoint to "Autoencoder_epoch_19.pkl"
# (Epoch 19 / 50) train reconstruct_error: 13.572116; val_reconstruct_error: 13.697146
# Saving checkpoint to "Autoencoder_epoch_20.pkl"
# (Epoch 20 / 50) train reconstruct_error: 13.502648; val_reconstruct_error: 13.629345
# Saving checkpoint to "Autoencoder_epoch_21.pkl"
# (Epoch 21 / 50) train reconstruct_error: 13.441614; val_reconstruct_error: 13.569559
# Saving checkpoint to "Autoencoder_epoch_22.pkl"
# (Epoch 22 / 50) train reconstruct_error: 13.387162; val_reconstruct_error: 13.516557
# Saving checkpoint to "Autoencoder_epoch_23.pkl"
# (Epoch 23 / 50) train reconstruct_error: 13.339002; val_reconstruct_error: 13.470198
# Saving checkpoint to "Autoencoder_epoch_24.pkl"
# (Epoch 24 / 50) train reconstruct_error: 13.296594; val_reconstruct_error: 13.429444
# Saving checkpoint to "Autoencoder_epoch_25.pkl"
# (Epoch 25 / 50) train reconstruct_error: 13.257982; val_reconstruct_error: 13.391355
# Saving checkpoint to "Autoencoder_epoch_26.pkl"
# (Epoch 26 / 50) train reconstruct_error: 13.223977; val_reconstruct_error: 13.358332
# Saving checkpoint to "Autoencoder_epoch_27.pkl"
# (Epoch 27 / 50) train reconstruct_error: 13.193673; val_reconstruct_error: 13.328088
# Saving checkpoint to "Autoencoder_epoch_28.pkl"
# (Epoch 28 / 50) train reconstruct_error: 13.166772; val_reconstruct_error: 13.301561
# Saving checkpoint to "Autoencoder_epoch_29.pkl"
# (Epoch 29 / 50) train reconstruct_error: 13.142451; val_reconstruct_error: 13.278137
# Saving checkpoint to "Autoencoder_epoch_30.pkl"
# (Epoch 30 / 50) train reconstruct_error: 13.120854; val_reconstruct_error: 13.257045
# Saving checkpoint to "Autoencoder_epoch_31.pkl"
# (Epoch 31 / 50) train reconstruct_error: 13.101594; val_reconstruct_error: 13.238021
# Saving checkpoint to "Autoencoder_epoch_32.pkl"
# (Epoch 32 / 50) train reconstruct_error: 13.084306; val_reconstruct_error: 13.221114
# Saving checkpoint to "Autoencoder_epoch_33.pkl"
# (Epoch 33 / 50) train reconstruct_error: 13.068803; val_reconstruct_error: 13.206013
# (Iteration 1001 / 1500) loss: 12.375928
# Saving checkpoint to "Autoencoder_epoch_34.pkl"
# (Epoch 34 / 50) train reconstruct_error: 13.054856; val_reconstruct_error: 13.192630
# Saving checkpoint to "Autoencoder_epoch_35.pkl"
# (Epoch 35 / 50) train reconstruct_error: 13.042386; val_reconstruct_error: 13.180338
# Saving checkpoint to "Autoencoder_epoch_36.pkl"
# (Epoch 36 / 50) train reconstruct_error: 13.031186; val_reconstruct_error: 13.169289
# Saving checkpoint to "Autoencoder_epoch_37.pkl"
# (Epoch 37 / 50) train reconstruct_error: 13.021152; val_reconstruct_error: 13.159593
# Saving checkpoint to "Autoencoder_epoch_38.pkl"
# (Epoch 38 / 50) train reconstruct_error: 13.012094; val_reconstruct_error: 13.150726
# Saving checkpoint to "Autoencoder_epoch_39.pkl"
# (Epoch 39 / 50) train reconstruct_error: 13.004140; val_reconstruct_error: 13.142833
# Saving checkpoint to "Autoencoder_epoch_40.pkl"
# (Epoch 40 / 50) train reconstruct_error: 12.996903; val_reconstruct_error: 13.135585
# Saving checkpoint to "Autoencoder_epoch_41.pkl"
# (Epoch 41 / 50) train reconstruct_error: 12.990344; val_reconstruct_error: 13.129240
# Saving checkpoint to "Autoencoder_epoch_42.pkl"
# (Epoch 42 / 50) train reconstruct_error: 12.984471; val_reconstruct_error: 13.123578
# Saving checkpoint to "Autoencoder_epoch_43.pkl"
# (Epoch 43 / 50) train reconstruct_error: 12.979171; val_reconstruct_error: 13.118531
# Saving checkpoint to "Autoencoder_epoch_44.pkl"
# (Epoch 44 / 50) train reconstruct_error: 12.974447; val_reconstruct_error: 13.113868
# Saving checkpoint to "Autoencoder_epoch_45.pkl"
# (Epoch 45 / 50) train reconstruct_error: 12.970179; val_reconstruct_error: 13.109667
# Saving checkpoint to "Autoencoder_epoch_46.pkl"
# (Epoch 46 / 50) train reconstruct_error: 12.966360; val_reconstruct_error: 13.105812
# Saving checkpoint to "Autoencoder_epoch_47.pkl"
# (Epoch 47 / 50) train reconstruct_error: 12.962959; val_reconstruct_error: 13.102480
# Saving checkpoint to "Autoencoder_epoch_48.pkl"
# (Epoch 48 / 50) train reconstruct_error: 12.959875; val_reconstruct_error: 13.099505
# Saving checkpoint to "Autoencoder_epoch_49.pkl"
# (Epoch 49 / 50) train reconstruct_error: 12.957115; val_reconstruct_error: 13.096813
# Saving checkpoint to "Autoencoder_epoch_50.pkl"
# (Epoch 50 / 50) train reconstruct_error: 12.954626; val_reconstruct_error: 13.094345

# %%
model = Autoencoder(input_dim=28*28, weight_scale=1e-1, hidden_dim=500)
solver = Solver(model, data, checkpoint_name='Autoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=50, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)
# Out:
# (Iteration 1 / 1500) loss: 108.718451
# Saving checkpoint to "Autoencoder_epoch_0.pkl"
# (Epoch 0 / 50) train reconstruct_error: 65.720887; val_reconstruct_error: 65.775564
# Saving checkpoint to "Autoencoder_epoch_1.pkl"
# (Epoch 1 / 50) train reconstruct_error: 15.788085; val_reconstruct_error: 15.840388
# Saving checkpoint to "Autoencoder_epoch_2.pkl"
# (Epoch 2 / 50) train reconstruct_error: 13.710496; val_reconstruct_error: 13.773929
# Saving checkpoint to "Autoencoder_epoch_3.pkl"
# (Epoch 3 / 50) train reconstruct_error: 12.429464; val_reconstruct_error: 12.512780
# Saving checkpoint to "Autoencoder_epoch_4.pkl"
# (Epoch 4 / 50) train reconstruct_error: 11.572765; val_reconstruct_error: 11.672891
# Saving checkpoint to "Autoencoder_epoch_5.pkl"
# (Epoch 5 / 50) train reconstruct_error: 10.938886; val_reconstruct_error: 11.046705
# Saving checkpoint to "Autoencoder_epoch_6.pkl"
# (Epoch 6 / 50) train reconstruct_error: 10.465857; val_reconstruct_error: 10.586719
# Saving checkpoint to "Autoencoder_epoch_7.pkl"
# (Epoch 7 / 50) train reconstruct_error: 10.092555; val_reconstruct_error: 10.217085
# Saving checkpoint to "Autoencoder_epoch_8.pkl"
# (Epoch 8 / 50) train reconstruct_error: 9.793598; val_reconstruct_error: 9.924368
# Saving checkpoint to "Autoencoder_epoch_9.pkl"
# (Epoch 9 / 50) train reconstruct_error: 9.549644; val_reconstruct_error: 9.682066
# Saving checkpoint to "Autoencoder_epoch_10.pkl"
# (Epoch 10 / 50) train reconstruct_error: 9.346813; val_reconstruct_error: 9.481957
# Saving checkpoint to "Autoencoder_epoch_11.pkl"
# (Epoch 11 / 50) train reconstruct_error: 9.176224; val_reconstruct_error: 9.316858
# Saving checkpoint to "Autoencoder_epoch_12.pkl"
# (Epoch 12 / 50) train reconstruct_error: 9.031192; val_reconstruct_error: 9.173581
# Saving checkpoint to "Autoencoder_epoch_13.pkl"
# (Epoch 13 / 50) train reconstruct_error: 8.905055; val_reconstruct_error: 9.051984
# Saving checkpoint to "Autoencoder_epoch_14.pkl"
# (Epoch 14 / 50) train reconstruct_error: 8.798011; val_reconstruct_error: 8.945881
# Saving checkpoint to "Autoencoder_epoch_15.pkl"
# (Epoch 15 / 50) train reconstruct_error: 8.704074; val_reconstruct_error: 8.855944
# Saving checkpoint to "Autoencoder_epoch_16.pkl"
# (Epoch 16 / 50) train reconstruct_error: 8.622620; val_reconstruct_error: 8.776525
# (Iteration 501 / 1500) loss: 8.749386
# Saving checkpoint to "Autoencoder_epoch_17.pkl"
# (Epoch 17 / 50) train reconstruct_error: 8.551797; val_reconstruct_error: 8.705806
# Saving checkpoint to "Autoencoder_epoch_18.pkl"
# (Epoch 18 / 50) train reconstruct_error: 8.488983; val_reconstruct_error: 8.643797
# Saving checkpoint to "Autoencoder_epoch_19.pkl"
# (Epoch 19 / 50) train reconstruct_error: 8.434222; val_reconstruct_error: 8.590257
# Saving checkpoint to "Autoencoder_epoch_20.pkl"
# (Epoch 20 / 50) train reconstruct_error: 8.385458; val_reconstruct_error: 8.542238
# Saving checkpoint to "Autoencoder_epoch_21.pkl"
# (Epoch 21 / 50) train reconstruct_error: 8.342428; val_reconstruct_error: 8.498339
# Saving checkpoint to "Autoencoder_epoch_22.pkl"
# (Epoch 22 / 50) train reconstruct_error: 8.304407; val_reconstruct_error: 8.462434
# Saving checkpoint to "Autoencoder_epoch_23.pkl"
# (Epoch 23 / 50) train reconstruct_error: 8.270363; val_reconstruct_error: 8.428343
# Saving checkpoint to "Autoencoder_epoch_24.pkl"
# (Epoch 24 / 50) train reconstruct_error: 8.240366; val_reconstruct_error: 8.398404
# Saving checkpoint to "Autoencoder_epoch_25.pkl"
# (Epoch 25 / 50) train reconstruct_error: 8.213811; val_reconstruct_error: 8.372410
# Saving checkpoint to "Autoencoder_epoch_26.pkl"
# (Epoch 26 / 50) train reconstruct_error: 8.190421; val_reconstruct_error: 8.349533
# Saving checkpoint to "Autoencoder_epoch_27.pkl"
# (Epoch 27 / 50) train reconstruct_error: 8.169187; val_reconstruct_error: 8.329481
# Saving checkpoint to "Autoencoder_epoch_28.pkl"
# (Epoch 28 / 50) train reconstruct_error: 8.150298; val_reconstruct_error: 8.310676
# Saving checkpoint to "Autoencoder_epoch_29.pkl"
# (Epoch 29 / 50) train reconstruct_error: 8.133339; val_reconstruct_error: 8.293872
# Saving checkpoint to "Autoencoder_epoch_30.pkl"
# (Epoch 30 / 50) train reconstruct_error: 8.118268; val_reconstruct_error: 8.278439
# Saving checkpoint to "Autoencoder_epoch_31.pkl"
# (Epoch 31 / 50) train reconstruct_error: 8.104808; val_reconstruct_error: 8.265165
# Saving checkpoint to "Autoencoder_epoch_32.pkl"
# (Epoch 32 / 50) train reconstruct_error: 8.092730; val_reconstruct_error: 8.253814
# Saving checkpoint to "Autoencoder_epoch_33.pkl"
# (Epoch 33 / 50) train reconstruct_error: 8.081792; val_reconstruct_error: 8.243580
# (Iteration 1001 / 1500) loss: 7.530373
# Saving checkpoint to "Autoencoder_epoch_34.pkl"
# (Epoch 34 / 50) train reconstruct_error: 8.072035; val_reconstruct_error: 8.234038
# Saving checkpoint to "Autoencoder_epoch_35.pkl"
# (Epoch 35 / 50) train reconstruct_error: 8.063202; val_reconstruct_error: 8.225220
# Saving checkpoint to "Autoencoder_epoch_36.pkl"
# (Epoch 36 / 50) train reconstruct_error: 8.055412; val_reconstruct_error: 8.217509
# Saving checkpoint to "Autoencoder_epoch_37.pkl"
# (Epoch 37 / 50) train reconstruct_error: 8.048437; val_reconstruct_error: 8.210540
# Saving checkpoint to "Autoencoder_epoch_38.pkl"
# (Epoch 38 / 50) train reconstruct_error: 8.042135; val_reconstruct_error: 8.204459
# Saving checkpoint to "Autoencoder_epoch_39.pkl"
# (Epoch 39 / 50) train reconstruct_error: 8.036456; val_reconstruct_error: 8.198901
# Saving checkpoint to "Autoencoder_epoch_40.pkl"
# (Epoch 40 / 50) train reconstruct_error: 8.031397; val_reconstruct_error: 8.193701
# Saving checkpoint to "Autoencoder_epoch_41.pkl"
# (Epoch 41 / 50) train reconstruct_error: 8.026825; val_reconstruct_error: 8.189370
# Saving checkpoint to "Autoencoder_epoch_42.pkl"
# (Epoch 42 / 50) train reconstruct_error: 8.022707; val_reconstruct_error: 8.185212
# Saving checkpoint to "Autoencoder_epoch_43.pkl"
# (Epoch 43 / 50) train reconstruct_error: 8.018994; val_reconstruct_error: 8.181692
# Saving checkpoint to "Autoencoder_epoch_44.pkl"
# (Epoch 44 / 50) train reconstruct_error: 8.015683; val_reconstruct_error: 8.178295
# Saving checkpoint to "Autoencoder_epoch_45.pkl"
# (Epoch 45 / 50) train reconstruct_error: 8.012711; val_reconstruct_error: 8.175385
# Saving checkpoint to "Autoencoder_epoch_46.pkl"
# (Epoch 46 / 50) train reconstruct_error: 8.010007; val_reconstruct_error: 8.172756
# Saving checkpoint to "Autoencoder_epoch_47.pkl"
# (Epoch 47 / 50) train reconstruct_error: 8.007625; val_reconstruct_error: 8.170453
# Saving checkpoint to "Autoencoder_epoch_48.pkl"
# (Epoch 48 / 50) train reconstruct_error: 8.005472; val_reconstruct_error: 8.168339
# Saving checkpoint to "Autoencoder_epoch_49.pkl"
# (Epoch 49 / 50) train reconstruct_error: 8.003508; val_reconstruct_error: 8.166445
# Saving checkpoint to "Autoencoder_epoch_50.pkl"
# (Epoch 50 / 50) train reconstruct_error: 8.001761; val_reconstruct_error: 8.164719

# %%
model = Autoencoder(input_dim=28*28, weight_scale=1e-1, hidden_dim=50, dropout_level=0.1)
solver = Solver(model, data, checkpoint_name='Autoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=50, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)
# Out:
# (Iteration 1 / 1500) loss: 92.456372
# Saving checkpoint to "Autoencoder_epoch_0.pkl"
# (Epoch 0 / 50) train reconstruct_error: 86.848325; val_reconstruct_error: 86.820570
# Saving checkpoint to "Autoencoder_epoch_1.pkl"
# (Epoch 1 / 50) train reconstruct_error: 36.784177; val_reconstruct_error: 36.916515
# Saving checkpoint to "Autoencoder_epoch_2.pkl"
# (Epoch 2 / 50) train reconstruct_error: 31.987056; val_reconstruct_error: 32.104107
# Saving checkpoint to "Autoencoder_epoch_3.pkl"
# (Epoch 3 / 50) train reconstruct_error: 29.714615; val_reconstruct_error: 29.828385
# Saving checkpoint to "Autoencoder_epoch_4.pkl"
# (Epoch 4 / 50) train reconstruct_error: 28.118434; val_reconstruct_error: 28.228916
# Saving checkpoint to "Autoencoder_epoch_5.pkl"
# (Epoch 5 / 50) train reconstruct_error: 26.912355; val_reconstruct_error: 26.994169
# Saving checkpoint to "Autoencoder_epoch_6.pkl"
# (Epoch 6 / 50) train reconstruct_error: 25.881807; val_reconstruct_error: 25.993946
# Saving checkpoint to "Autoencoder_epoch_7.pkl"
# (Epoch 7 / 50) train reconstruct_error: 25.069103; val_reconstruct_error: 25.165438
# Saving checkpoint to "Autoencoder_epoch_8.pkl"
# (Epoch 8 / 50) train reconstruct_error: 24.397672; val_reconstruct_error: 24.511141
# Saving checkpoint to "Autoencoder_epoch_9.pkl"
# (Epoch 9 / 50) train reconstruct_error: 23.834166; val_reconstruct_error: 23.946100
# Saving checkpoint to "Autoencoder_epoch_10.pkl"
# (Epoch 10 / 50) train reconstruct_error: 23.372321; val_reconstruct_error: 23.490928
# Saving checkpoint to "Autoencoder_epoch_11.pkl"
# (Epoch 11 / 50) train reconstruct_error: 22.994974; val_reconstruct_error: 23.099771
# Saving checkpoint to "Autoencoder_epoch_12.pkl"
# (Epoch 12 / 50) train reconstruct_error: 22.669101; val_reconstruct_error: 22.790672
# Saving checkpoint to "Autoencoder_epoch_13.pkl"
# (Epoch 13 / 50) train reconstruct_error: 22.392818; val_reconstruct_error: 22.517862
# Saving checkpoint to "Autoencoder_epoch_14.pkl"
# (Epoch 14 / 50) train reconstruct_error: 22.157124; val_reconstruct_error: 22.270137
# Saving checkpoint to "Autoencoder_epoch_15.pkl"
# (Epoch 15 / 50) train reconstruct_error: 21.950000; val_reconstruct_error: 22.062998
# Saving checkpoint to "Autoencoder_epoch_16.pkl"
# (Epoch 16 / 50) train reconstruct_error: 21.776852; val_reconstruct_error: 21.903322
# (Iteration 501 / 1500) loss: 21.395221
# Saving checkpoint to "Autoencoder_epoch_17.pkl"
# (Epoch 17 / 50) train reconstruct_error: 21.626229; val_reconstruct_error: 21.758485
# Saving checkpoint to "Autoencoder_epoch_18.pkl"
# (Epoch 18 / 50) train reconstruct_error: 21.488654; val_reconstruct_error: 21.616866
# Saving checkpoint to "Autoencoder_epoch_19.pkl"
# (Epoch 19 / 50) train reconstruct_error: 21.376897; val_reconstruct_error: 21.508743
# Saving checkpoint to "Autoencoder_epoch_20.pkl"
# (Epoch 20 / 50) train reconstruct_error: 21.275438; val_reconstruct_error: 21.396978
# Saving checkpoint to "Autoencoder_epoch_21.pkl"
# (Epoch 21 / 50) train reconstruct_error: 21.189209; val_reconstruct_error: 21.308393
# Saving checkpoint to "Autoencoder_epoch_22.pkl"
# (Epoch 22 / 50) train reconstruct_error: 21.102444; val_reconstruct_error: 21.229599
# Saving checkpoint to "Autoencoder_epoch_23.pkl"
# (Epoch 23 / 50) train reconstruct_error: 21.031028; val_reconstruct_error: 21.153095
# Saving checkpoint to "Autoencoder_epoch_24.pkl"
# (Epoch 24 / 50) train reconstruct_error: 20.971840; val_reconstruct_error: 21.100514
# Saving checkpoint to "Autoencoder_epoch_25.pkl"
# (Epoch 25 / 50) train reconstruct_error: 20.917095; val_reconstruct_error: 21.051228
# Saving checkpoint to "Autoencoder_epoch_26.pkl"
# (Epoch 26 / 50) train reconstruct_error: 20.870020; val_reconstruct_error: 21.004088
# Saving checkpoint to "Autoencoder_epoch_27.pkl"
# (Epoch 27 / 50) train reconstruct_error: 20.828548; val_reconstruct_error: 20.952881
# Saving checkpoint to "Autoencoder_epoch_28.pkl"
# (Epoch 28 / 50) train reconstruct_error: 20.791633; val_reconstruct_error: 20.923656
# Saving checkpoint to "Autoencoder_epoch_29.pkl"
# (Epoch 29 / 50) train reconstruct_error: 20.755277; val_reconstruct_error: 20.885573
# Saving checkpoint to "Autoencoder_epoch_30.pkl"
# (Epoch 30 / 50) train reconstruct_error: 20.723264; val_reconstruct_error: 20.855950
# Saving checkpoint to "Autoencoder_epoch_31.pkl"
# (Epoch 31 / 50) train reconstruct_error: 20.698313; val_reconstruct_error: 20.824505
# Saving checkpoint to "Autoencoder_epoch_32.pkl"
# (Epoch 32 / 50) train reconstruct_error: 20.671652; val_reconstruct_error: 20.809068
# Saving checkpoint to "Autoencoder_epoch_33.pkl"
# (Epoch 33 / 50) train reconstruct_error: 20.645521; val_reconstruct_error: 20.776426
# (Iteration 1001 / 1500) loss: 19.815604
# Saving checkpoint to "Autoencoder_epoch_34.pkl"
# (Epoch 34 / 50) train reconstruct_error: 20.633278; val_reconstruct_error: 20.765612
# Saving checkpoint to "Autoencoder_epoch_35.pkl"
# (Epoch 35 / 50) train reconstruct_error: 20.608702; val_reconstruct_error: 20.744343
# Saving checkpoint to "Autoencoder_epoch_36.pkl"
# (Epoch 36 / 50) train reconstruct_error: 20.597468; val_reconstruct_error: 20.731138
# Saving checkpoint to "Autoencoder_epoch_37.pkl"
# (Epoch 37 / 50) train reconstruct_error: 20.585588; val_reconstruct_error: 20.725474
# Saving checkpoint to "Autoencoder_epoch_38.pkl"
# (Epoch 38 / 50) train reconstruct_error: 20.572472; val_reconstruct_error: 20.708470
# Saving checkpoint to "Autoencoder_epoch_39.pkl"
# (Epoch 39 / 50) train reconstruct_error: 20.554107; val_reconstruct_error: 20.696565
# Saving checkpoint to "Autoencoder_epoch_40.pkl"
# (Epoch 40 / 50) train reconstruct_error: 20.550035; val_reconstruct_error: 20.693333
# Saving checkpoint to "Autoencoder_epoch_41.pkl"
# (Epoch 41 / 50) train reconstruct_error: 20.540250; val_reconstruct_error: 20.672180
# Saving checkpoint to "Autoencoder_epoch_42.pkl"
# (Epoch 42 / 50) train reconstruct_error: 20.535427; val_reconstruct_error: 20.663319
# Saving checkpoint to "Autoencoder_epoch_43.pkl"
# (Epoch 43 / 50) train reconstruct_error: 20.529495; val_reconstruct_error: 20.663672
# Saving checkpoint to "Autoencoder_epoch_44.pkl"
# (Epoch 44 / 50) train reconstruct_error: 20.518448; val_reconstruct_error: 20.656575
# Saving checkpoint to "Autoencoder_epoch_45.pkl"
# (Epoch 45 / 50) train reconstruct_error: 20.511803; val_reconstruct_error: 20.647643
# Saving checkpoint to "Autoencoder_epoch_46.pkl"
# (Epoch 46 / 50) train reconstruct_error: 20.502817; val_reconstruct_error: 20.637134
# Saving checkpoint to "Autoencoder_epoch_47.pkl"
# (Epoch 47 / 50) train reconstruct_error: 20.498689; val_reconstruct_error: 20.643615
# Saving checkpoint to "Autoencoder_epoch_48.pkl"
# (Epoch 48 / 50) train reconstruct_error: 20.499692; val_reconstruct_error: 20.639713
# Saving checkpoint to "Autoencoder_epoch_49.pkl"
# (Epoch 49 / 50) train reconstruct_error: 20.496887; val_reconstruct_error: 20.630164
# Saving checkpoint to "Autoencoder_epoch_50.pkl"
# (Epoch 50 / 50) train reconstruct_error: 20.489873; val_reconstruct_error: 20.633801

# %%
model = Autoencoder(input_dim=28*28, weight_scale=1e-1, hidden_dim=100, dropout_level=0.1)
solver = Solver(model, data, checkpoint_name='Autoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=50, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)
# Out:
# (Iteration 1 / 1500) loss: 94.488200
# Saving checkpoint to "Autoencoder_epoch_0.pkl"
# (Epoch 0 / 50) train reconstruct_error: 83.506117; val_reconstruct_error: 83.471230
# Saving checkpoint to "Autoencoder_epoch_1.pkl"
# (Epoch 1 / 50) train reconstruct_error: 31.291919; val_reconstruct_error: 31.369742
# Saving checkpoint to "Autoencoder_epoch_2.pkl"
# (Epoch 2 / 50) train reconstruct_error: 27.335984; val_reconstruct_error: 27.400106
# Saving checkpoint to "Autoencoder_epoch_3.pkl"
# (Epoch 3 / 50) train reconstruct_error: 25.103234; val_reconstruct_error: 25.163074
# Saving checkpoint to "Autoencoder_epoch_4.pkl"
# (Epoch 4 / 50) train reconstruct_error: 23.501962; val_reconstruct_error: 23.581700
# Saving checkpoint to "Autoencoder_epoch_5.pkl"
# (Epoch 5 / 50) train reconstruct_error: 22.306104; val_reconstruct_error: 22.385686
# Saving checkpoint to "Autoencoder_epoch_6.pkl"
# (Epoch 6 / 50) train reconstruct_error: 21.408836; val_reconstruct_error: 21.481391
# Saving checkpoint to "Autoencoder_epoch_7.pkl"
# (Epoch 7 / 50) train reconstruct_error: 20.690231; val_reconstruct_error: 20.774613
# Saving checkpoint to "Autoencoder_epoch_8.pkl"
# (Epoch 8 / 50) train reconstruct_error: 20.126627; val_reconstruct_error: 20.225459
# Saving checkpoint to "Autoencoder_epoch_9.pkl"
# (Epoch 9 / 50) train reconstruct_error: 19.680653; val_reconstruct_error: 19.777530
# Saving checkpoint to "Autoencoder_epoch_10.pkl"
# (Epoch 10 / 50) train reconstruct_error: 19.307639; val_reconstruct_error: 19.397040
# Saving checkpoint to "Autoencoder_epoch_11.pkl"
# (Epoch 11 / 50) train reconstruct_error: 19.002258; val_reconstruct_error: 19.112437
# Saving checkpoint to "Autoencoder_epoch_12.pkl"
# (Epoch 12 / 50) train reconstruct_error: 18.743244; val_reconstruct_error: 18.848532
# Saving checkpoint to "Autoencoder_epoch_13.pkl"
# (Epoch 13 / 50) train reconstruct_error: 18.521143; val_reconstruct_error: 18.625329
# Saving checkpoint to "Autoencoder_epoch_14.pkl"
# (Epoch 14 / 50) train reconstruct_error: 18.331279; val_reconstruct_error: 18.427628
# Saving checkpoint to "Autoencoder_epoch_15.pkl"
# (Epoch 15 / 50) train reconstruct_error: 18.169622; val_reconstruct_error: 18.275791
# Saving checkpoint to "Autoencoder_epoch_16.pkl"
# (Epoch 16 / 50) train reconstruct_error: 18.031704; val_reconstruct_error: 18.133043
# (Iteration 501 / 1500) loss: 18.068657
# Saving checkpoint to "Autoencoder_epoch_17.pkl"
# (Epoch 17 / 50) train reconstruct_error: 17.906709; val_reconstruct_error: 18.015401
# Saving checkpoint to "Autoencoder_epoch_18.pkl"
# (Epoch 18 / 50) train reconstruct_error: 17.798433; val_reconstruct_error: 17.918799
# Saving checkpoint to "Autoencoder_epoch_19.pkl"
# (Epoch 19 / 50) train reconstruct_error: 17.714899; val_reconstruct_error: 17.813391
# Saving checkpoint to "Autoencoder_epoch_20.pkl"
# (Epoch 20 / 50) train reconstruct_error: 17.621079; val_reconstruct_error: 17.736517
# Saving checkpoint to "Autoencoder_epoch_21.pkl"
# (Epoch 21 / 50) train reconstruct_error: 17.557800; val_reconstruct_error: 17.679568
# Saving checkpoint to "Autoencoder_epoch_22.pkl"
# (Epoch 22 / 50) train reconstruct_error: 17.492298; val_reconstruct_error: 17.615529
# Saving checkpoint to "Autoencoder_epoch_23.pkl"
# (Epoch 23 / 50) train reconstruct_error: 17.438266; val_reconstruct_error: 17.542216
# Saving checkpoint to "Autoencoder_epoch_24.pkl"
# (Epoch 24 / 50) train reconstruct_error: 17.389091; val_reconstruct_error: 17.496770
# Saving checkpoint to "Autoencoder_epoch_25.pkl"
# (Epoch 25 / 50) train reconstruct_error: 17.342204; val_reconstruct_error: 17.451488
# Saving checkpoint to "Autoencoder_epoch_26.pkl"
# (Epoch 26 / 50) train reconstruct_error: 17.303697; val_reconstruct_error: 17.409943
# Saving checkpoint to "Autoencoder_epoch_27.pkl"
# (Epoch 27 / 50) train reconstruct_error: 17.264295; val_reconstruct_error: 17.380244
# Saving checkpoint to "Autoencoder_epoch_28.pkl"
# (Epoch 28 / 50) train reconstruct_error: 17.237589; val_reconstruct_error: 17.348107
# Saving checkpoint to "Autoencoder_epoch_29.pkl"
# (Epoch 29 / 50) train reconstruct_error: 17.202633; val_reconstruct_error: 17.330712
# Saving checkpoint to "Autoencoder_epoch_30.pkl"
# (Epoch 30 / 50) train reconstruct_error: 17.184642; val_reconstruct_error: 17.295625
# Saving checkpoint to "Autoencoder_epoch_31.pkl"
# (Epoch 31 / 50) train reconstruct_error: 17.158111; val_reconstruct_error: 17.265472
# Saving checkpoint to "Autoencoder_epoch_32.pkl"
# (Epoch 32 / 50) train reconstruct_error: 17.142085; val_reconstruct_error: 17.255580
# Saving checkpoint to "Autoencoder_epoch_33.pkl"
# (Epoch 33 / 50) train reconstruct_error: 17.118680; val_reconstruct_error: 17.242185
# (Iteration 1001 / 1500) loss: 17.281346
# Saving checkpoint to "Autoencoder_epoch_34.pkl"
# (Epoch 34 / 50) train reconstruct_error: 17.104734; val_reconstruct_error: 17.228405
# Saving checkpoint to "Autoencoder_epoch_35.pkl"
# (Epoch 35 / 50) train reconstruct_error: 17.090062; val_reconstruct_error: 17.207570
# Saving checkpoint to "Autoencoder_epoch_36.pkl"
# (Epoch 36 / 50) train reconstruct_error: 17.080271; val_reconstruct_error: 17.190214
# Saving checkpoint to "Autoencoder_epoch_37.pkl"
# (Epoch 37 / 50) train reconstruct_error: 17.058898; val_reconstruct_error: 17.180327
# Saving checkpoint to "Autoencoder_epoch_38.pkl"
# (Epoch 38 / 50) train reconstruct_error: 17.057528; val_reconstruct_error: 17.170105
# Saving checkpoint to "Autoencoder_epoch_39.pkl"
# (Epoch 39 / 50) train reconstruct_error: 17.046052; val_reconstruct_error: 17.159600
# Saving checkpoint to "Autoencoder_epoch_40.pkl"
# (Epoch 40 / 50) train reconstruct_error: 17.030848; val_reconstruct_error: 17.155773
# Saving checkpoint to "Autoencoder_epoch_41.pkl"
# (Epoch 41 / 50) train reconstruct_error: 17.033697; val_reconstruct_error: 17.148384
# Saving checkpoint to "Autoencoder_epoch_42.pkl"
# (Epoch 42 / 50) train reconstruct_error: 17.021077; val_reconstruct_error: 17.156746
# Saving checkpoint to "Autoencoder_epoch_43.pkl"
# (Epoch 43 / 50) train reconstruct_error: 17.016021; val_reconstruct_error: 17.134037
# Saving checkpoint to "Autoencoder_epoch_44.pkl"
# (Epoch 44 / 50) train reconstruct_error: 17.010838; val_reconstruct_error: 17.128404
# Saving checkpoint to "Autoencoder_epoch_45.pkl"
# (Epoch 45 / 50) train reconstruct_error: 17.010439; val_reconstruct_error: 17.123788
# Saving checkpoint to "Autoencoder_epoch_46.pkl"
# (Epoch 46 / 50) train reconstruct_error: 17.004376; val_reconstruct_error: 17.120035
# Saving checkpoint to "Autoencoder_epoch_47.pkl"
# (Epoch 47 / 50) train reconstruct_error: 16.999272; val_reconstruct_error: 17.125269
# Saving checkpoint to "Autoencoder_epoch_48.pkl"
# (Epoch 48 / 50) train reconstruct_error: 16.994526; val_reconstruct_error: 17.110077
# Saving checkpoint to "Autoencoder_epoch_49.pkl"
# (Epoch 49 / 50) train reconstruct_error: 16.989763; val_reconstruct_error: 17.109096
# Saving checkpoint to "Autoencoder_epoch_50.pkl"
# (Epoch 50 / 50) train reconstruct_error: 16.991469; val_reconstruct_error: 17.107096

# %%
model = Autoencoder(input_dim=28*28, weight_scale=1e-1, hidden_dim=200, dropout_level=0.1)
solver = Solver(model, data, checkpoint_name='Autoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=50, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)
# Out:
# (Iteration 1 / 1500) loss: 99.107160
# Saving checkpoint to "Autoencoder_epoch_0.pkl"
# (Epoch 0 / 50) train reconstruct_error: 79.362836; val_reconstruct_error: 79.293709
# Saving checkpoint to "Autoencoder_epoch_1.pkl"
# (Epoch 1 / 50) train reconstruct_error: 25.129090; val_reconstruct_error: 25.197559
# Saving checkpoint to "Autoencoder_epoch_2.pkl"
# (Epoch 2 / 50) train reconstruct_error: 21.956480; val_reconstruct_error: 22.030836
# Saving checkpoint to "Autoencoder_epoch_3.pkl"
# (Epoch 3 / 50) train reconstruct_error: 20.099517; val_reconstruct_error: 20.196890
# Saving checkpoint to "Autoencoder_epoch_4.pkl"
# (Epoch 4 / 50) train reconstruct_error: 18.807926; val_reconstruct_error: 18.919304
# Saving checkpoint to "Autoencoder_epoch_5.pkl"
# (Epoch 5 / 50) train reconstruct_error: 17.861364; val_reconstruct_error: 17.958000
# Saving checkpoint to "Autoencoder_epoch_6.pkl"
# (Epoch 6 / 50) train reconstruct_error: 17.134428; val_reconstruct_error: 17.249377
# Saving checkpoint to "Autoencoder_epoch_7.pkl"
# (Epoch 7 / 50) train reconstruct_error: 16.572374; val_reconstruct_error: 16.700064
# Saving checkpoint to "Autoencoder_epoch_8.pkl"
# (Epoch 8 / 50) train reconstruct_error: 16.126214; val_reconstruct_error: 16.252003
# Saving checkpoint to "Autoencoder_epoch_9.pkl"
# (Epoch 9 / 50) train reconstruct_error: 15.756108; val_reconstruct_error: 15.895232
# Saving checkpoint to "Autoencoder_epoch_10.pkl"
# (Epoch 10 / 50) train reconstruct_error: 15.462063; val_reconstruct_error: 15.590921
# Saving checkpoint to "Autoencoder_epoch_11.pkl"
# (Epoch 11 / 50) train reconstruct_error: 15.204463; val_reconstruct_error: 15.335628
# Saving checkpoint to "Autoencoder_epoch_12.pkl"
# (Epoch 12 / 50) train reconstruct_error: 14.988358; val_reconstruct_error: 15.137677
# Saving checkpoint to "Autoencoder_epoch_13.pkl"
# (Epoch 13 / 50) train reconstruct_error: 14.806609; val_reconstruct_error: 14.957401
# Saving checkpoint to "Autoencoder_epoch_14.pkl"
# (Epoch 14 / 50) train reconstruct_error: 14.653816; val_reconstruct_error: 14.799902
# Saving checkpoint to "Autoencoder_epoch_15.pkl"
# (Epoch 15 / 50) train reconstruct_error: 14.509890; val_reconstruct_error: 14.663213
# Saving checkpoint to "Autoencoder_epoch_16.pkl"
# (Epoch 16 / 50) train reconstruct_error: 14.399083; val_reconstruct_error: 14.545778
# (Iteration 501 / 1500) loss: 13.781872
# Saving checkpoint to "Autoencoder_epoch_17.pkl"
# (Epoch 17 / 50) train reconstruct_error: 14.304192; val_reconstruct_error: 14.455334
# Saving checkpoint to "Autoencoder_epoch_18.pkl"
# (Epoch 18 / 50) train reconstruct_error: 14.210351; val_reconstruct_error: 14.351345
# Saving checkpoint to "Autoencoder_epoch_19.pkl"
# (Epoch 19 / 50) train reconstruct_error: 14.125642; val_reconstruct_error: 14.278261
# Saving checkpoint to "Autoencoder_epoch_20.pkl"
# (Epoch 20 / 50) train reconstruct_error: 14.056559; val_reconstruct_error: 14.207781
# Saving checkpoint to "Autoencoder_epoch_21.pkl"
# (Epoch 21 / 50) train reconstruct_error: 13.998755; val_reconstruct_error: 14.147133
# Saving checkpoint to "Autoencoder_epoch_22.pkl"
# (Epoch 22 / 50) train reconstruct_error: 13.931960; val_reconstruct_error: 14.106066
# Saving checkpoint to "Autoencoder_epoch_23.pkl"
# (Epoch 23 / 50) train reconstruct_error: 13.895610; val_reconstruct_error: 14.033207
# Saving checkpoint to "Autoencoder_epoch_24.pkl"
# (Epoch 24 / 50) train reconstruct_error: 13.847159; val_reconstruct_error: 13.993317
# Saving checkpoint to "Autoencoder_epoch_25.pkl"
# (Epoch 25 / 50) train reconstruct_error: 13.809296; val_reconstruct_error: 13.971893
# Saving checkpoint to "Autoencoder_epoch_26.pkl"
# (Epoch 26 / 50) train reconstruct_error: 13.779095; val_reconstruct_error: 13.932185
# Saving checkpoint to "Autoencoder_epoch_27.pkl"
# (Epoch 27 / 50) train reconstruct_error: 13.747259; val_reconstruct_error: 13.914245
# Saving checkpoint to "Autoencoder_epoch_28.pkl"
# (Epoch 28 / 50) train reconstruct_error: 13.715699; val_reconstruct_error: 13.875066
# Saving checkpoint to "Autoencoder_epoch_29.pkl"
# (Epoch 29 / 50) train reconstruct_error: 13.701970; val_reconstruct_error: 13.857670
# Saving checkpoint to "Autoencoder_epoch_30.pkl"
# (Epoch 30 / 50) train reconstruct_error: 13.679369; val_reconstruct_error: 13.839043
# Saving checkpoint to "Autoencoder_epoch_31.pkl"
# (Epoch 31 / 50) train reconstruct_error: 13.652890; val_reconstruct_error: 13.804401
# Saving checkpoint to "Autoencoder_epoch_32.pkl"
# (Epoch 32 / 50) train reconstruct_error: 13.640139; val_reconstruct_error: 13.804321
# Saving checkpoint to "Autoencoder_epoch_33.pkl"
# (Epoch 33 / 50) train reconstruct_error: 13.620784; val_reconstruct_error: 13.785885
# (Iteration 1001 / 1500) loss: 13.555160
# Saving checkpoint to "Autoencoder_epoch_34.pkl"
# (Epoch 34 / 50) train reconstruct_error: 13.603372; val_reconstruct_error: 13.772569
# Saving checkpoint to "Autoencoder_epoch_35.pkl"
# (Epoch 35 / 50) train reconstruct_error: 13.600230; val_reconstruct_error: 13.753639
# Saving checkpoint to "Autoencoder_epoch_36.pkl"
# (Epoch 36 / 50) train reconstruct_error: 13.583729; val_reconstruct_error: 13.743850
# Saving checkpoint to "Autoencoder_epoch_37.pkl"
# (Epoch 37 / 50) train reconstruct_error: 13.567471; val_reconstruct_error: 13.729358
# Saving checkpoint to "Autoencoder_epoch_38.pkl"
# (Epoch 38 / 50) train reconstruct_error: 13.562754; val_reconstruct_error: 13.726148
# Saving checkpoint to "Autoencoder_epoch_39.pkl"
# (Epoch 39 / 50) train reconstruct_error: 13.555164; val_reconstruct_error: 13.718719
# Saving checkpoint to "Autoencoder_epoch_40.pkl"
# (Epoch 40 / 50) train reconstruct_error: 13.548909; val_reconstruct_error: 13.719808
# Saving checkpoint to "Autoencoder_epoch_41.pkl"
# (Epoch 41 / 50) train reconstruct_error: 13.533208; val_reconstruct_error: 13.714310
# Saving checkpoint to "Autoencoder_epoch_42.pkl"
# (Epoch 42 / 50) train reconstruct_error: 13.533395; val_reconstruct_error: 13.700450
# Saving checkpoint to "Autoencoder_epoch_43.pkl"
# (Epoch 43 / 50) train reconstruct_error: 13.530738; val_reconstruct_error: 13.698659
# Saving checkpoint to "Autoencoder_epoch_44.pkl"
# (Epoch 44 / 50) train reconstruct_error: 13.533295; val_reconstruct_error: 13.694540
# Saving checkpoint to "Autoencoder_epoch_45.pkl"
# (Epoch 45 / 50) train reconstruct_error: 13.521311; val_reconstruct_error: 13.687340
# Saving checkpoint to "Autoencoder_epoch_46.pkl"
# (Epoch 46 / 50) train reconstruct_error: 13.514698; val_reconstruct_error: 13.689090
# Saving checkpoint to "Autoencoder_epoch_47.pkl"
# (Epoch 47 / 50) train reconstruct_error: 13.520757; val_reconstruct_error: 13.676682
# Saving checkpoint to "Autoencoder_epoch_48.pkl"
# (Epoch 48 / 50) train reconstruct_error: 13.515807; val_reconstruct_error: 13.676401
# Saving checkpoint to "Autoencoder_epoch_49.pkl"
# (Epoch 49 / 50) train reconstruct_error: 13.510372; val_reconstruct_error: 13.662201
# Saving checkpoint to "Autoencoder_epoch_50.pkl"
# (Epoch 50 / 50) train reconstruct_error: 13.507489; val_reconstruct_error: 13.667406

# %%
model = Autoencoder(input_dim=28*28, weight_scale=1e-1, hidden_dim=500, dropout_level=0.1)
solver = Solver(model, data, checkpoint_name='Autoencoder', update_rule='sgd', \
                 optim_config={'learning_rate': 0.05}, print_every=500, lr_decay=0.9, num_epochs=50, batch_size=100)
solver.train_unsupervise()
plot_solver(solver)
# Out:
# (Iteration 1 / 1500) loss: 108.781248
# Saving checkpoint to "Autoencoder_epoch_0.pkl"
# (Epoch 0 / 50) train reconstruct_error: 67.265888; val_reconstruct_error: 67.278465
# Saving checkpoint to "Autoencoder_epoch_1.pkl"
# (Epoch 1 / 50) train reconstruct_error: 17.049428; val_reconstruct_error: 17.070630
# Saving checkpoint to "Autoencoder_epoch_2.pkl"
# (Epoch 2 / 50) train reconstruct_error: 15.018067; val_reconstruct_error: 15.066868
# Saving checkpoint to "Autoencoder_epoch_3.pkl"
# (Epoch 3 / 50) train reconstruct_error: 13.723569; val_reconstruct_error: 13.767178
# Saving checkpoint to "Autoencoder_epoch_4.pkl"
# (Epoch 4 / 50) train reconstruct_error: 12.801365; val_reconstruct_error: 12.861724
# Saving checkpoint to "Autoencoder_epoch_5.pkl"
# (Epoch 5 / 50) train reconstruct_error: 12.130364; val_reconstruct_error: 12.192779
# Saving checkpoint to "Autoencoder_epoch_6.pkl"
# (Epoch 6 / 50) train reconstruct_error: 11.599630; val_reconstruct_error: 11.701620
# Saving checkpoint to "Autoencoder_epoch_7.pkl"
# (Epoch 7 / 50) train reconstruct_error: 11.216801; val_reconstruct_error: 11.315747
# Saving checkpoint to "Autoencoder_epoch_8.pkl"
# (Epoch 8 / 50) train reconstruct_error: 10.896346; val_reconstruct_error: 11.000075
# Saving checkpoint to "Autoencoder_epoch_9.pkl"
# (Epoch 9 / 50) train reconstruct_error: 10.632203; val_reconstruct_error: 10.742681
# Saving checkpoint to "Autoencoder_epoch_10.pkl"
# (Epoch 10 / 50) train reconstruct_error: 10.420563; val_reconstruct_error: 10.517019
# Saving checkpoint to "Autoencoder_epoch_11.pkl"
# (Epoch 11 / 50) train reconstruct_error: 10.232244; val_reconstruct_error: 10.338909
# Saving checkpoint to "Autoencoder_epoch_12.pkl"
# (Epoch 12 / 50) train reconstruct_error: 10.084035; val_reconstruct_error: 10.182274
# Saving checkpoint to "Autoencoder_epoch_13.pkl"
# (Epoch 13 / 50) train reconstruct_error: 9.948122; val_reconstruct_error: 10.038359
# Saving checkpoint to "Autoencoder_epoch_14.pkl"
# (Epoch 14 / 50) train reconstruct_error: 9.836949; val_reconstruct_error: 9.944657
# Saving checkpoint to "Autoencoder_epoch_15.pkl"
# (Epoch 15 / 50) train reconstruct_error: 9.732621; val_reconstruct_error: 9.846716
# Saving checkpoint to "Autoencoder_epoch_16.pkl"
# (Epoch 16 / 50) train reconstruct_error: 9.645238; val_reconstruct_error: 9.781015
# (Iteration 501 / 1500) loss: 9.247572
# Saving checkpoint to "Autoencoder_epoch_17.pkl"
# (Epoch 17 / 50) train reconstruct_error: 9.574154; val_reconstruct_error: 9.691820
# Saving checkpoint to "Autoencoder_epoch_18.pkl"
# (Epoch 18 / 50) train reconstruct_error: 9.512636; val_reconstruct_error: 9.625437
# Saving checkpoint to "Autoencoder_epoch_19.pkl"
# (Epoch 19 / 50) train reconstruct_error: 9.449668; val_reconstruct_error: 9.563649
# Saving checkpoint to "Autoencoder_epoch_20.pkl"
# (Epoch 20 / 50) train reconstruct_error: 9.410162; val_reconstruct_error: 9.533611
# Saving checkpoint to "Autoencoder_epoch_21.pkl"
# (Epoch 21 / 50) train reconstruct_error: 9.357534; val_reconstruct_error: 9.496737
# Saving checkpoint to "Autoencoder_epoch_22.pkl"
# (Epoch 22 / 50) train reconstruct_error: 9.316368; val_reconstruct_error: 9.454254
# Saving checkpoint to "Autoencoder_epoch_23.pkl"
# (Epoch 23 / 50) train reconstruct_error: 9.272440; val_reconstruct_error: 9.414837
# Saving checkpoint to "Autoencoder_epoch_24.pkl"
# (Epoch 24 / 50) train reconstruct_error: 9.249887; val_reconstruct_error: 9.386873
# Saving checkpoint to "Autoencoder_epoch_25.pkl"
# (Epoch 25 / 50) train reconstruct_error: 9.225940; val_reconstruct_error: 9.364510
# Saving checkpoint to "Autoencoder_epoch_26.pkl"
# (Epoch 26 / 50) train reconstruct_error: 9.192914; val_reconstruct_error: 9.326004
# Saving checkpoint to "Autoencoder_epoch_27.pkl"
# (Epoch 27 / 50) train reconstruct_error: 9.177776; val_reconstruct_error: 9.302289
# Saving checkpoint to "Autoencoder_epoch_28.pkl"
# (Epoch 28 / 50) train reconstruct_error: 9.147112; val_reconstruct_error: 9.288334
# Saving checkpoint to "Autoencoder_epoch_29.pkl"
# (Epoch 29 / 50) train reconstruct_error: 9.132871; val_reconstruct_error: 9.285387
# Saving checkpoint to "Autoencoder_epoch_30.pkl"
# (Epoch 30 / 50) train reconstruct_error: 9.127457; val_reconstruct_error: 9.263205
# Saving checkpoint to "Autoencoder_epoch_31.pkl"
# (Epoch 31 / 50) train reconstruct_error: 9.109839; val_reconstruct_error: 9.235434
# Saving checkpoint to "Autoencoder_epoch_32.pkl"
# (Epoch 32 / 50) train reconstruct_error: 9.103631; val_reconstruct_error: 9.224848
# Saving checkpoint to "Autoencoder_epoch_33.pkl"
# (Epoch 33 / 50) train reconstruct_error: 9.089103; val_reconstruct_error: 9.231532
# (Iteration 1001 / 1500) loss: 8.744625
# Saving checkpoint to "Autoencoder_epoch_34.pkl"
# (Epoch 34 / 50) train reconstruct_error: 9.076813; val_reconstruct_error: 9.198840
# Saving checkpoint to "Autoencoder_epoch_35.pkl"
# (Epoch 35 / 50) train reconstruct_error: 9.059872; val_reconstruct_error: 9.203352
# Saving checkpoint to "Autoencoder_epoch_36.pkl"
# (Epoch 36 / 50) train reconstruct_error: 9.052828; val_reconstruct_error: 9.179911
# Saving checkpoint to "Autoencoder_epoch_37.pkl"
# (Epoch 37 / 50) train reconstruct_error: 9.056505; val_reconstruct_error: 9.169536
# Saving checkpoint to "Autoencoder_epoch_38.pkl"
# (Epoch 38 / 50) train reconstruct_error: 9.047940; val_reconstruct_error: 9.154627
# Saving checkpoint to "Autoencoder_epoch_39.pkl"
# (Epoch 39 / 50) train reconstruct_error: 9.032606; val_reconstruct_error: 9.157895
# Saving checkpoint to "Autoencoder_epoch_40.pkl"
# (Epoch 40 / 50) train reconstruct_error: 9.030998; val_reconstruct_error: 9.170318
# Saving checkpoint to "Autoencoder_epoch_41.pkl"
# (Epoch 41 / 50) train reconstruct_error: 9.033430; val_reconstruct_error: 9.153561
# Saving checkpoint to "Autoencoder_epoch_42.pkl"
# (Epoch 42 / 50) train reconstruct_error: 9.018352; val_reconstruct_error: 9.153717
# Saving checkpoint to "Autoencoder_epoch_43.pkl"
# (Epoch 43 / 50) train reconstruct_error: 9.010465; val_reconstruct_error: 9.158101
# Saving checkpoint to "Autoencoder_epoch_44.pkl"
# (Epoch 44 / 50) train reconstruct_error: 9.020074; val_reconstruct_error: 9.149532
# Saving checkpoint to "Autoencoder_epoch_45.pkl"
# (Epoch 45 / 50) train reconstruct_error: 9.018227; val_reconstruct_error: 9.162510
# Saving checkpoint to "Autoencoder_epoch_46.pkl"
# (Epoch 46 / 50) train reconstruct_error: 9.007480; val_reconstruct_error: 9.137361
# Saving checkpoint to "Autoencoder_epoch_47.pkl"
# (Epoch 47 / 50) train reconstruct_error: 9.011422; val_reconstruct_error: 9.148521
# Saving checkpoint to "Autoencoder_epoch_48.pkl"
# (Epoch 48 / 50) train reconstruct_error: 9.000382; val_reconstruct_error: 9.152231
# Saving checkpoint to "Autoencoder_epoch_49.pkl"
# (Epoch 49 / 50) train reconstruct_error: 8.999316; val_reconstruct_error: 9.138438
# Saving checkpoint to "Autoencoder_epoch_50.pkl"
# (Epoch 50 / 50) train reconstruct_error: 8.996359; val_reconstruct_error: 9.132365
